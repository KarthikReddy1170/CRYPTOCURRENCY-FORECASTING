# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("C:\PROJECTS\AI FOR DS PROJECT\AI FOR DS PROJECT\DATASET2\ethereum.csv")

# %%
dataset
# Out:
#             Date     Open     High      Low    Close  Volume Currency  \
# 0     2016-03-10    11.20    11.85    11.07    11.75       4      USD
# 1     2016-03-11    11.75    11.95    11.75    11.95     179      USD
# 2     2016-03-12    11.95    13.45    11.95    12.92     833      USD
# 3     2016-03-13    12.92    15.07    12.92    15.07    1295      USD
# 4     2016-03-14    15.07    15.07    11.40    12.50   92183      USD
# ...          ...      ...      ...      ...      ...     ...      ...
# 2118  2021-12-27  4062.02  4125.22  4033.04  4036.24  313319      USD
# 2119  2021-12-28  4036.86  4036.86  3760.86  3791.69  527234      USD
# 2120  2021-12-29  3792.95  3825.97  3607.20  3627.93  456030      USD
# 2121  2021-12-30  3629.33  3767.93  3589.64  3709.57  355717      USD
# 2122  2021-12-31  3709.38  3812.01  3623.74  3677.85  405653      USD
#
#       prediction
# 0          12.92
# 1          15.07
# 2          12.50
# 3          13.06
# 4          12.88
# ...          ...
# 2118     3627.93
# 2119     3709.57
# 2120     3677.85
# 2121         NaN
# 2122         NaN
#
# [2123 rows x 8 columns]

# %%
projection =2
dataset['prediction']=dataset[['Close']].shift(-projection)
dataset
# Out:
#             Date     Open     High      Low    Close  Volume Currency  \
# 0     2016-03-10    11.20    11.85    11.07    11.75       4      USD
# 1     2016-03-11    11.75    11.95    11.75    11.95     179      USD
# 2     2016-03-12    11.95    13.45    11.95    12.92     833      USD
# 3     2016-03-13    12.92    15.07    12.92    15.07    1295      USD
# 4     2016-03-14    15.07    15.07    11.40    12.50   92183      USD
# ...          ...      ...      ...      ...      ...     ...      ...
# 2118  2021-12-27  4062.02  4125.22  4033.04  4036.24  313319      USD
# 2119  2021-12-28  4036.86  4036.86  3760.86  3791.69  527234      USD
# 2120  2021-12-29  3792.95  3825.97  3607.20  3627.93  456030      USD
# 2121  2021-12-30  3629.33  3767.93  3589.64  3709.57  355717      USD
# 2122  2021-12-31  3709.38  3812.01  3623.74  3677.85  405653      USD
#
#       prediction
# 0          12.92
# 1          15.07
# 2          12.50
# 3          13.06
# 4          12.88
# ...          ...
# 2118     3627.93
# 2119     3709.57
# 2120     3677.85
# 2121         NaN
# 2122         NaN
#
# [2123 rows x 8 columns]

# %%
X=np.array(dataset[['Close']])
X=X[:-projection]
print(X)
# Out:
# [[  11.75]
#  [  11.95]
#  [  12.92]
#  ...
#  [4036.24]
#  [3791.69]
#  [3627.93]]

# %%
Y=dataset['prediction'].values
Y=Y[:-projection]
print(Y)
# Out:
# [  12.92   15.07   12.5  ... 3627.93 3709.57 3677.85]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size= .15)

# %%
linereg=LinearRegression()
linereg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
linereg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17500/1589618419.py in <module>
# ----> 1 linereg
#
# NameError: name 'linereg' is not defined
